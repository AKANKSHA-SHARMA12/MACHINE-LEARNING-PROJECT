# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("churn.csv")

# %%
dataset.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# State             3333 non-null object
# Account Length    3333 non-null int64
# Area Code         3333 non-null int64
# Phone             3333 non-null object
# Int'l Plan        3333 non-null object
# VMail Plan        3333 non-null object
# VMail Message     3333 non-null int64
# Day Mins          3333 non-null float64
# Day Calls         3333 non-null int64
# Day Charge        3333 non-null float64
# Eve Mins          3333 non-null float64
# Eve Calls         3333 non-null int64
# Eve Charge        3333 non-null float64
# Night Mins        3333 non-null float64
# Night Calls       3333 non-null int64
# Night Charge      3333 non-null float64
# Intl Mins         3333 non-null float64
# Intl Calls        3333 non-null int64
# Intl Charge       3333 non-null float64
# CustServ Calls    3333 non-null int64
# Churn?            3333 non-null object
# ...

# %%
dataset.describe()
# Out:
#        Account Length    Area Code  VMail Message     Day Mins    Day Calls  \
# count     3333.000000  3333.000000    3333.000000  3333.000000  3333.000000
# mean       101.064806   437.182418       8.099010   179.775098   100.435644
# std         39.822106    42.371290      13.688365    54.467389    20.069084
# min          1.000000   408.000000       0.000000     0.000000     0.000000
# 25%         74.000000   408.000000       0.000000   143.700000    87.000000
# 50%        101.000000   415.000000       0.000000   179.400000   101.000000
# 75%        127.000000   510.000000      20.000000   216.400000   114.000000
# max        243.000000   510.000000      51.000000   350.800000   165.000000
#
#         Day Charge     Eve Mins    Eve Calls   Eve Charge   Night Mins  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean     30.562307   200.980348   100.114311    17.083540   200.872037
# ...

# %%
dataset.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'Int'l Plan',
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge',
#        'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls',
#        'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge',
#        'CustServ Calls', 'Churn?'],
#       dtype='object')

# %%
dataset['Phone']=dataset['Phone'].str.replace("-","")
dataset['Phone']=dataset['Phone'].astype(int)

# %%
dataset.head()
# Out:
#   State  Account Length  Area Code    Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  3824657         no        yes
# 1    OH             107        415  3717191         no        yes
# 2    NJ             137        415  3581921         no         no
# 3    OH              84        408  3759999        yes         no
# 4    OK              75        415  3306626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
X=dataset.columns[dataset.dtypes=="O"]
X.values
# Out:
# array(['State', "Int'l Plan", 'VMail Plan', 'Churn?'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in X.values:
    dataset[i]=le.fit_transform(dataset[i].astype(str))

# %%
dataset.head()
# Out:
#    State  Account Length  Area Code    Phone  Int'l Plan  VMail Plan  \
# 0     16             128        415  3824657           0           1
# 1     35             107        415  3717191           0           1
# 2     31             137        415  3581921           0           0
# 3     35              84        408  3759999           1           0
# 4     36              75        415  3306626           1           0
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
dataset.isna().sum()
# Out:
# State             0
# Account Length    0
# Area Code         0
# Phone             0
# Int'l Plan        0
# VMail Plan        0
# VMail Message     0
# Day Mins          0
# Day Calls         0
# Day Charge        0
# Eve Mins          0
# Eve Calls         0
# Eve Charge        0
# Night Mins        0
# Night Calls       0
# Night Charge      0
# Intl Mins         0
# Intl Calls        0
# Intl Charge       0
# CustServ Calls    0
# Churn?            0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'Int'l Plan',
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge',
#        'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls',
#        'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge',
#        'CustServ Calls', 'Churn?'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
new=ss.fit_transform(dataset.drop('Churn?',axis=1).values)

# %%
data=pd.DataFrame(data=new,columns=['State', 'Account Length', 'Area Code', 'Phone', "'Int'l Plan",
       'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge',
       'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls',
       'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge',
       'CustServ Calls'])
data.head()
# Out:
#       State  Account Length  Area Code     Phone  'Int'l Plan  VMail Plan  \
# 0 -0.678649        0.676489  -0.523603  0.285359    -0.327580    1.617086
# 1  0.603170        0.149065  -0.523603 -0.105965    -0.327580    1.617086
# 2  0.333313        0.902529  -0.523603 -0.598534    -0.327580   -0.618396
# 3  0.603170       -0.428590  -0.688834  0.049915     3.052685   -0.618396
# 4  0.670634       -0.654629  -0.523603 -1.600987     3.052685   -0.618396
#
#    VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0       1.234883  1.566767   0.476643    1.567036 -0.070610  -0.055940
# 1       1.307948 -0.333738   1.124503   -0.334013 -0.108080   0.144867
# 2      -0.591760  1.168304   0.675985    1.168464 -1.573383   0.496279
# 3      -0.591760  2.196596  -1.466936    2.196759 -2.742865  -0.608159
# 4      -0.591760 -0.240090   0.626149   -0.240041 -1.038932   1.098699
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
cor=data.corrwith(dataset.iloc[:,-1])
cor
# Out:
# State             0.007780
# Account Length    0.016541
# Area Code         0.006174
# Phone             0.005730
# 'Int'l Plan       0.259852
# VMail Plan       -0.102148
# VMail Message    -0.089728
# Day Mins          0.205151
# Day Calls         0.018459
# Day Charge        0.205151
# Eve Mins          0.092796
# Eve Calls         0.009233
# Eve Charge        0.092786
# Night Mins        0.035493
# Night Calls       0.006141
# Night Charge      0.035496
# Intl Mins         0.068239
# Intl Calls       -0.052844
# Intl Charge       0.068259
# CustServ Calls    0.208750
# dtype: float64

# %%
X=data[['State', 'Account Length', 'Area Code', "'Int'l Plan",
       'Day Mins', 'Day Calls', 'Day Charge', 'Eve Mins', 'Eve Calls',
       'Eve Charge', 'Night Mins', 'Night Calls', 'Night Charge', 'Intl Mins',
       'Intl Charge', 'CustServ Calls']]

# %%
Y=dataset["Churn?"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=2000,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,Y_train)
knn.score(X_train,Y_train)
# Out:
# 0.9028507126781695

# %%
pred=knn.predict(X_test)
knn.score(X_test,Y_test)
# Out:
# 0.863568215892054

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(confusion_matrix(Y_test,pred))
# Out:
# [[553  11]
#  [ 80  23]]

# %%
print(classification_report(Y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       564
#            1       0.68      0.22      0.34       103
#
#    micro avg       0.86      0.86      0.86       667
#    macro avg       0.78      0.60      0.63       667
# weighted avg       0.84      0.86      0.83       667

# %%
from sklearn.linear_model import LogisticRegression
clf =LogisticRegression()
fitted_model = clf.fit(X_train, Y_train)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
clf.score(X_train, Y_train)
# Out:
# 0.8574643660915229

# %%
prediction=clf.predict(X_test)

# %%
clf.score(X_test,Y_test)
# Out:
# 0.8515742128935532

# %%
tc=DecisionTreeClassifier(max_depth=4)
tc.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
tc.score(X_train,Y_train)
# Out:
# 0.921980495123781

# %%
pred1=clf.predict(X_test)

# %%
tc.score(X_test,Y_test)
# Out:
# 0.9010494752623688

# %%
import graphviz
from sklearn import tree

# %%
dot_data=tree.export_graphviz(tc)

# %%
import os
os.environ["PATH"] += os.pathsep + r'C:\Program Files (x86)\Graphviz2.38\bin'

# %%
graph=graphviz.Source(dot_data)
graph

# %%
tc.feature_importances_
# Out:
# array([0.01185321, 0.        , 0.        , 0.12651594, 0.24017778,
#        0.        , 0.15802069, 0.05967042, 0.        , 0.0302152 ,
#        0.02325794, 0.        , 0.01762685, 0.        , 0.12637376,
#        0.20628822])

# %%
param={"max_depth":[3,4,5,6,7,8],"max_leaf_nodes":[3,4,5,6,7,8]}

# %%
from sklearn.model_selection import GridSearchCV
grid=GridSearchCV(tc ,param,cv=5)
grid.fit(X_train,Y_train)
grid.score(X_train,Y_train)
# Out:
# 0.9118529632408102

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=8, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
tc1=DecisionTreeClassifier( max_depth=3, max_leaf_nodes=8,)
tc1.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=8, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
tc1.score(X_train,Y_train)
# Out:
# 0.9118529632408102

# %%
pred2=clf.predict(X_test)

# %%
tc1.score(X_test,Y_test)
# Out:
# 0.9010494752623688

# %%
dot_data1=tree.export_graphviz(tc1)

# %%
graph1=graphviz.Source(dot_data1)
graph1
